# %% [markdown]
# <a href="https://colab.research.google.com/github/molnedit4/git-demo/blob/main/Save_and_load_patient_visit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_visit = pd.read_csv('/content/Demo Hospital Outpatient Data_NHC.csv')
df_visit
# Out:
# <ipython-input-3-5e22ed9abb4b>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_visit = pd.read_csv('/content/Demo Hospital Outpatient Data_NHC.csv')
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
# 274509  2018-11-01      361308   24  Female
#
#                                 Diagnosis Has_Insurance  Postcode  Total_Cost  \
# 0                                Diabetes          True   20006.0      2274.0
# ...

# %%
df_visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274510 entries, 0 to 274509
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Visit_Date     274510 non-null  object
#  1   Patient_ID     274510 non-null  int64
#  2   Age            274510 non-null  int64
#  3   Gender         274510 non-null  object
#  4   Diagnosis      274510 non-null  object
#  5   Has_Insurance  274510 non-null  object
#  6   Postcode       274509 non-null  float64
#  7   Total_Cost     274509 non-null  float64
#  8   Registration   274509 non-null  float64
#  9   Nursing        274509 non-null  float64
#  10  Laboratory     274509 non-null  float64
#  11  Consultation   274509 non-null  float64
#  12  Pharmacy       274509 non-null  float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 27.2+ MB

# %%
df_visit.isna().sum()
# Out:
# Visit_Date       0
# Patient_ID       0
# Age              0
# Gender           0
# Diagnosis        0
# Has_Insurance    0
# Postcode         1
# Total_Cost       1
# Registration     1
# Nursing          1
# Laboratory       1
# Consultation     1
# Pharmacy         1
# dtype: int64

# %%
df_visit.dropna()
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274504  2018-08-03      332528   36    Male
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
#
#                                 Diagnosis Has_Insurance  Postcode  Total_Cost  \
# 0                                Diabetes          True   20006.0      2274.0
# 1                 Urinary Tract Infection         False   20005.0      3430.0
# 2       Upper Respiratory Tract Infection          True   10003.0      1836.0
# 3       Upper Respiratory Tract Infection         False   10006.0      3250.0
# ...

# %%
df_visit = df_visit.dropna()
df_visit
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274504  2018-08-03      332528   36    Male
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
#
#                                 Diagnosis Has_Insurance  Postcode  Total_Cost  \
# 0                                Diabetes          True   20006.0      2274.0
# 1                 Urinary Tract Infection         False   20005.0      3430.0
# 2       Upper Respiratory Tract Infection          True   10003.0      1836.0
# 3       Upper Respiratory Tract Infection         False   10006.0      3250.0
# ...

# %%
df_visit.head(20)
# Out:
#     Visit_Date  Patient_ID  Age  Gender                          Diagnosis  \
# 0   2020-05-06      688923   68  Female                           Diabetes
# 1   2018-08-04      886361   62  Female            Urinary Tract Infection
# 2   2021-04-10      464823   70  Female  Upper Respiratory Tract Infection
# 3   2021-10-01      655214    8  Female  Upper Respiratory Tract Infection
# 4   2018-04-30      454666   24    Male                            Malaria
# 5   2022-06-22       47297   14    Male                      Ear Infection
# 6   2022-03-30      703464   52    Male            Urinary Tract Infection
# 7   2021-12-19      969327   44  Female                            Malaria
# 8   2020-09-16      246521   55    Male                           Diabetes
# 9   2022-04-23      796347   68  Female                           Diabetes
# 10  2018-02-22      920307   84    Male                            Malaria
# ...

# %%
df_visit.rename(columns={'Registration' : 'Registration_minutes'})
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274504  2018-08-03      332528   36    Male
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
#
#                                 Diagnosis Has_Insurance  Postcode  Total_Cost  \
# 0                                Diabetes          True   20006.0      2274.0
# 1                 Urinary Tract Infection         False   20005.0      3430.0
# 2       Upper Respiratory Tract Infection          True   10003.0      1836.0
# 3       Upper Respiratory Tract Infection         False   10006.0      3250.0
# ...

# %%
df_visit.rename(columns={'Registration' : 'Registration_minutes'}, inplace=True) # inplace -> make the changes to the original df as well

# %%
column_mapping = {'Nursing': 'Nursing_minutes', 'Laboratory' :'Laboratory_minutes', 'Consultation': 'Consultation_minutes', 'Pharmacy': 'Pharmacy_minutes'}

# %%
df_visit.rename(columns=column_mapping, inplace=True)
df_visit
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274504  2018-08-03      332528   36    Male
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
#
#                                 Diagnosis Has_Insurance  Postcode  Total_Cost  \
# 0                                Diabetes          True   20006.0      2274.0
# 1                 Urinary Tract Infection         False   20005.0      3430.0
# 2       Upper Respiratory Tract Infection          True   10003.0      1836.0
# 3       Upper Respiratory Tract Infection         False   10006.0      3250.0
# ...

# %% [markdown]
# Save and Load Patient

# %%
df_visit.to_csv('/content/Clean_Demo_Hospital_Outpatient_Data_NHC.csv', index = False)

# %%
df_visit.to_excel('/content/Clean_Demo_Hospital_Outpatient_Data_NHC.xlsx', index = False)

# %%
pd.read_excel('/content/Clean_Demo_Hospital_Outpatient_Data_NHC.xlsx')
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274504  2018-08-03      332528   36    Male
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True     20006
# 1                 Urinary Tract Infection          False     20005
# 2       Upper Respiratory Tract Infection           True     10003
# 3       Upper Respiratory Tract Infection          False     10006
# 4                                 Malaria           True     10006
# ...

# %%
import zipfile

# %%
zipped_file_name = 'demo_hospital_outpatient_data_clean.zip'

# %%
with zipfile.ZipFile(zipped_file_name, 'w',zipfile.ZIP_DEFLATED) as zip:
  zip.write('/content/Clean_Demo_Hospital_Outpatient_Data_NHC.csv')

# %%
pd.read_csv('/content/demo_hospital_outpatient_data_clean.zip') # we can see that file size and loading time are correlated. File size in increasing order: zipfile < csvfile < excelfile
# Out:
#         Visit_Date  Patient_ID  Age  Gender  \
# 0       2020-05-06      688923   68  Female
# 1       2018-08-04      886361   62  Female
# 2       2021-04-10      464823   70  Female
# 3       2021-10-01      655214    8  Female
# 4       2018-04-30      454666   24    Male
# ...            ...         ...  ...     ...
# 274504  2018-08-03      332528   36    Male
# 274505  2020-05-09      728725    7    Male
# 274506  2019-09-21      719969   57  Female
# 274507  2019-10-05      678255   24    Male
# 274508  2021-11-26      177824   60    Male
#
#                                 Diagnosis  Has_Insurance  Postcode  \
# 0                                Diabetes           True   20006.0
# 1                 Urinary Tract Infection          False   20005.0
# 2       Upper Respiratory Tract Infection           True   10003.0
# 3       Upper Respiratory Tract Infection          False   10006.0
# 4                                 Malaria           True   10006.0
# ...

# %%
# !pip install pyreadstat
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 11.3 MB/s eta 0:00:00
# ...

# %%
import pyreadstat

# %%
spss_file = 'demo_hospital_outpatient_data_clean.sav'

# %%
pyreadstat.write_sav(df_visit, spss_file)

# %%
data, meta = pyreadstat.read_sav('/content/demo_hospital_outpatient_data_clean.sav')

# %%
data
# Out:
#         Visit_Date  Patient_ID   Age  Gender  \
# 0       2020-05-06    688923.0  68.0  Female
# 1       2018-08-04    886361.0  62.0  Female
# 2       2021-04-10    464823.0  70.0  Female
# 3       2021-10-01    655214.0   8.0  Female
# 4       2018-04-30    454666.0  24.0    Male
# ...            ...         ...   ...     ...
# 274504  2018-08-03    332528.0  36.0    Male
# 274505  2020-05-09    728725.0   7.0    Male
# 274506  2019-09-21    719969.0  57.0  Female
# 274507  2019-10-05    678255.0  24.0    Male
# 274508  2021-11-26    177824.0  60.0    Male
#
#                                 Diagnosis Has_Insurance  Postcode  Total_Cost  \
# 0                                Diabetes          True   20006.0      2274.0
# 1                 Urinary Tract Infection         False   20005.0      3430.0
# 2       Upper Respiratory Tract Infection          True   10003.0      1836.0
# 3       Upper Respiratory Tract Infection         False   10006.0      3250.0
# ...

# %%
meta

# %%
df_visit = pd.DataFrame(data)
